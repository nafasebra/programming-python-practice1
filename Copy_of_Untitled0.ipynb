# %% [markdown]
# <a href="https://colab.research.google.com/github/nafasebra/programming-python-practice1/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Fatemeh_yarandi
#p1
a=int(input("inter a:"))
m=int(input("inter m:"))
sum=a+m
print("sum is",sum)
print("")
minus=a-m
print("minus is",minus)
print("")
multiplication=a*m
print("multiplication is",multiplication)
print("")
division=a/m
print("division is",division)
print("")
leftover=a%m
print("leftover is",leftover)
print("")
correct_division=a//m
print("correct_division is",correct_division)
print("")
power=a**m
print("power a**m is",power)

#p2
number1=int(input("inter number1: "))
number2=int(input("inter number2: "))
print("number1:",number1>=number2 and number1==number2)
print("number1:",number1==number2 or number1>number2)
print("number1:",number1<number2 & number1<number2)
print("number1:",number1==number2 | number1<number2)

#p3
number1=int(input("inter number1: "))
number2=int(input("inter number2: "))
print("")
print("bainry number1:",bin(number1))
print("")
print("bainry number2:",bin(number2))
print("")
print("sum bainry:",bin(number1+number2))
print("")
print("minus bainry:",bin(number1-number2))
print("")
print("multiplication bainry:",bin(number1*number2))
print("")
print("division bainry:",bin(number1/number2))
print("")
print("mod bainry:",bin(number1%number2))
print("")
print("correct_division bainry:",bin(number1//number2))
print("")
print("power bainry:",bin(number1**number2))


#p4
number1=int(input("inter number1: "))
number2=int(input("inter number2: "))
print("")
print("oct number1:",oct(number1))
print("")
print("oct number2:",oct(number2))
print("")
print("sum oct:",oct(number1+number2))
print("")
print("minus oct:",oct(number1-number2))
print("")
print("multiplication oct:",oct(number1*number2))
print("")
print("division oct:",oct(number1/number2))
print("")
print("mod oct:",oct(number1%number2))
print("")
print("correct_division oct:",oct(number1//number2))
print("")
print("power oct:",oct(number1**number2))

#p5
number1=int(input("inter number1: "))
number2=int(input("inter number2: "))
print("")
print("hex number1:",hex(number1))
print("")
print("hex number2:",hex(number2))
print("")
print("sum hex:",hex(number1+number2))
print("")
print("minus hex:",hex(number1-number2))
print("")
print("multiplication hex:",hex(number1*number2))
print("")
print("division hex:",hex(number1/number2))
print("")
print("mod hex:",hex(number1%number2))
print("")
print("correct_division hex:",hex(number1//number2))
print("")
print("power hex:",hex(number1**number2))
